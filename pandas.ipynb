# %% [markdown]
# <a href="https://colab.research.google.com/github/ajaycpp/data-structure/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
salesdata={"Salesman Name":["Mohan", "Ramesh", "Abhay", "Ganesh"],
           "Zone":["South", "North", "East","West"],
           "Total Amount":[12000, 23000,14500,16720]}
print(salesdata)
mydataset=pd.DataFrame(salesdata)
#mydataset.head(3)
mydataset.tail(2)
mydataset.describe()
# Out:
# {'Salesman Name': ['Mohan', 'Ramesh', 'Abhay', 'Ganesh'], 'Zone': ['South', 'North', 'East', 'West'], 'Total Amount': [12000, 23000, 14500, 16720]}
#        Total Amount
# count      4.000000
# mean   16555.000000
# std     4709.433795
# min    12000.000000
# 25%    13875.000000
# 50%    15610.000000
# 75%    18290.000000
# max    23000.000000
